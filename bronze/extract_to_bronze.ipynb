# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, col, sum, count


 
import urllib.request

url = "https://dbc-8cfd0b99-8a79.cloud.databricks.com/editor/notebooks/101116335207097?o=3904245752872997"
response = urllib.request.urlopen(url)
code = response.read().decode("utf-8")

exec(code)  # выполняет содержимое файла как Python код
# ------------------------------------------------------
# STEP 0: Start Spark session
# ------------------------------------------------------
spark = SparkSession.builder.getOrCreate()

# ------------------------------------------------------
# STEP 1: Bronze Layer
# Load raw CSV from S3 into a DataFrame
# ------------------------------------------------------
s3_path = "s3a://private-markets-lakehouse-elena/investments_VC.csv"

df_bronze_investments_VC = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(s3_path)

# Show first 5 rows of the raw data
df_bronze_investments_VC.show(5)
